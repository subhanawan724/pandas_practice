# %%
import os

print(os.getcwd())
# Out:
# d:\practice.py

# %%
import pandas as pd


df = pd.read_csv(r"C:\Users\hp\Downloads\archive\StudentPerformanceFactors.csv")

print(df.head())
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
import sweetviz as sv
report =sv.analyze(df)
report.show_html('report.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
import pandas as pd

# GitHub ka direct raw data link
url = "https://raw.githubusercontent.com/subhanawan724/pandas_practice/main/StudentPerformanceFactors.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df = pd.DataFrame(df)

# %%
df.columns.tolist()
# Out:
# ['Hours_Studied',
#  'Attendance',
#  'Parental_Involvement',
#  'Access_to_Resources',
#  'Extracurricular_Activities',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Motivation_Level',
#  'Internet_Access',
#  'Tutoring_Sessions',
#  'Family_Income',
#  'Teacher_Quality',
#  'School_Type',
#  'Peer_Influence',
#  'Physical_Activity',
#  'Learning_Disabilities',
#  'Parental_Education_Level',
#  'Distance_from_Home',
#  'Gender',
#  'Exam_Score']

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score  Total_Score  \
# count        6607.000000        6607.000000  6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659   142.306190
# std             1.230570           1.031231     3.890456    15.559753
# min             0.000000           0.000000    55.000000   109.000000
# ...

# %%
df.min()
# Out:
# Hours_Studied                        1
# Attendance                          60
# Parental_Involvement              High
# Access_to_Resources               High
# Extracurricular_Activities          No
# Sleep_Hours                          4
# Previous_Scores                     50
# Motivation_Level                  High
# Internet_Access                     No
# Tutoring_Sessions                    0
# Family_Income                     High
# Teacher_Quality                   High
# School_Type                    Private
# Peer_Influence                Negative
# Physical_Activity                    0
# Learning_Disabilities               No
# Parental_Education_Level       College
# Distance_from_Home                 Far
# Gender                          Female
# Exam_Score                          55
# Total_Score                        109
# Average                           54.5
# dtype: object

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
print(df.loc[0]["Distance_from_Home"])
# Out:
# Near

# %%
temp = df[df["Hours_Studied"] == df["Hours_Studied"].max()]

print(type(df))
print(type(temp))

print(temp.head())
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.DataFrame'>
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 2895             44          68                 High                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 2895                         No            9               75
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 2895              Low             Yes                  3        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 2895            High     Private       Negative                  2
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 2895                    No              High School           Moderate
#
#       Gender  Exam_Score
# 2895  Female          71

# %%
temp = df[df["Hours_Studied"] == df["Hours_Studied"].max()]

print(temp["Attendance"])
# Out:
# 2895    68
# Name: Attendance, dtype: int64

# %%
print(df[df["Exam_Score"] == df["Exam_Score"].max()]["Gender"])
# Out:
# 1525    Female
# Name: Gender, dtype: str

# %%
print(df[df["Attendance"]>90]["Exam_Score"])
# Out:
# 2       74
# 4       70
# 8       69
# 9       72
# 11      71
#         ..
# 6592    72
# 6596    66
# 6597    70
# 6599    70
# 6600    67
# Name: Exam_Score, Length: 1590, dtype: int64

# %%
print(df.groupby("Gender")["Exam_Score"].mean())
# Out:
# Gender
# Female    67.244898
# Male      67.228894
# Name: Exam_Score, dtype: float64

# %%
import matplotlib.pyplot as plt 
plt.scatter(df["Hours_Studied"],df["Exam_Score"])

# %%
comp=(df.groupby("Gender")["Exam_Score"].mean())
plt.bar(comp.index, comp.values)
plt.xlabel("Gender")
plt.ylabel("Average Exam Score")
plt.title("Exam Scores by Gender")
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      3814
# Female    2793
# Name: count, dtype: int64

# %%
plt.hist(df["Sleep_Hours"],bins=10)
plt.show()

# %%
df["Gender"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.show()

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
hs=df[
    (df["Tutoring_Sessions"] > 5) & (df["Previous_Scores"] > 89)
]
print(hs[["Sleep_Hours", "Hours_Studied"]])

plt.bar(hs["Tutoring_Sessions"], hs["Previous_Scores"])
plt.xlabel("Tutoring Sessions")
plt.ylabel("Previous Scores")
plt.title("Effect of Tutoring Sessions on Previous Scores")
plt.show()
# Out:
#       Sleep_Hours  Hours_Studied
# 1848            6             26
# 2040            6             16
# 2198            4             16
# 3388            8             25
# 3617            6             18
# 4697            5             28
# 5680            6             14
# 5855            6              9
# 6485            8             35

# %%
import numpy as np
import matplotlib.pyplot as plt
passmark=33

# %%
df['PassStatus'] = np.where(df['Exam_Score'] > passmark, 'P', 'F')
df.PassStatus.value_counts()
# Out:
# PassStatus
# P    6605
# F       2
# Name: count, dtype: int64

# %%
plt.bar(df.PassStatus.value_counts().index, df.PassStatus.value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.PassStatus.value_counts().plot(
    kind="pie",autopct="%1.1f%%"
)

plt.show()

# %%
import seaborn as sns

# %%
p = sns.countplot(x="Exam_Score", data = df, palette="muted")
_ = plt.setp(p.get_xticklabels(), rotation=90)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18296\3798033123.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   p = sns.countplot(x="Exam_Score", data = df, palette="muted")

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='str')

# %%
tem= df.groupby("Family_Income")["Previous_Scores"].mean()
plt.pie(tem.values,labels=tem.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20724ea0550>,
# ...
#  [Text(0.5551862142037232, 0.949614799567771, 'High'),
#   Text(-1.0999661564766954, 0.008628708239719042, 'Low'),
#   Text(0.5477202854064646, -0.9539405059825593, 'Medium')],
#  [Text(0.30282884411112165, 0.5179717088551478, '33.2%'),
#   Text(-0.5999815398963793, 0.004706568130755841, '33.4%'),
#   Text(0.298756519312617, -0.5203311850813959, '33.4%')])

# %%
tem= df.groupby("Gender")["Sleep_Hours"].mean()
plt.pie(tem.values,labels=tem.index,autopct="%1.1f%%")
print(tem)
# Out:
# Gender
# Female    7.041890
# Male      7.019664
# Name: Sleep_Hours, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(
    data=df,
    x="Gender"
)
plt.show()

# %%
df.nunique()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Peer_Influence                 3
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
df["Total_Score"]= df["Exam_Score"]+df["Previous_Scores"]
df["Average"]= df["Total_Score"]/2
print(df[["Gender","Average"]].head(),"\n")
print(df[df["Average"]>90][["Gender","Average"]])
# Out:
#    Gender  Average
# 0    Male     70.0
# 1  Female     60.0
# 2    Male     82.5
# 3    Male     84.5
# 4  Female     67.5
#
#       Gender  Average
# 529   Female     97.0
# 770   Female     93.5
# 836     Male     95.0
# 919     Male     95.5
# 1525  Female     97.0
# 1607    Male     90.5
# 2425    Male     94.0
# 3124  Female     92.0
# 3579  Female     92.5
# 4192  Female     94.5
# 4297  Female     91.5
# 4405    Male     92.0
# 4531  Female     94.0
# 6347    Male     98.0
# 6393  Female     95.0

# %%
fig,axs =plt.subplots(1,2,figsize=(15,6))
plt.subplot(1,2,1)
sns.histplot(data=df,x='Average',bins=30,kde=True,color='g')
plt.subplot(1,2,2)
sns.histplot(data=df,x='Average',kde=True,hue='Gender')
plt.show()

# %%
fig,axs =plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x="Average",bins=30,kde=True,color='g')
plt.title("Distribution of Average Scores")
plt.xlabel("Average Scores")
plt.ylabel("Frequency")

plt.subplot(122)
sns.histplot(data=df,x="Average",bins=30,kde=True,multiple="dodge",hue="Gender")# if we dont use dodge color will overlap is common place and in reult we will se 3rd color i.e silver
plt.title('Distribution of Average Scores by Gender')
plt.xlabel('Average Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Create a subplot with three histograms side by side
plt.subplots(1, 3, figsize=(25, 6))

# Plot the first histogram with KDE, differentiated by sleep hours (Overall)
plt.subplot(1,3,1)
sns.histplot(data=df, x='Average', kde=True,hue="Internet_Access")
plt.title('Distribution of Average Scores by Internet_Access (Overall)')
plt.xlabel('Average Score')
plt.ylabel('Frequency')

# Plot the second histogram with KDE, differentiated by sleep hours (Female)
plt.subplot(1,3,2)
sns.histplot(data=df[df.Gender=='Female'], x='Average', kde=True, hue='Internet_Access')
plt.title('Distribution of Average Scores by  Internet_Access (Female)')
plt.xlabel('Average Score')
plt.ylabel('Frequency')

# Plot the third histogram with KDE, differentiated by sleep hours (Male)
plt.subplot(1,3,3)
sns.histplot(data=df[df.Gender=='Male'], x='Average', kde=True, hue='Internet_Access')
plt.title('Distribution of Average Scores by  Internet_Access (Male)')
plt.xlabel('Average Score')
plt.ylabel('Frequency')

# Display the subplots
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,hue = 'Internet_Access')
plt.show()

# %%
sns.pairplot(
    df[
        [
           
            "Hours_Studied",
            "Previous_Scores",
            "Exam_Score",
            "Total_Score"
        ]
    ]
)

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   str
#  3   Access_to_Resources         6607 non-null   str
#  4   Extracurricular_Activities  6607 non-null   str
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   str
#  8   Internet_Access             6607 non-null   str
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   str
#  11  Teacher_Quality             6529 non-null   str
#  12  School_Type                 6607 non-null   str
#  13  Peer_Influence              6607 non-null   str
# ...

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12,8))

sns.heatmap(
    corr,
    annot=True
)

plt.show()
